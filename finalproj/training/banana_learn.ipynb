# %%
# !rm -rf training
# !cp /content/drive/MyDrive/ML_IoT/training.zip ./

# %%
# !unzip -q training.zip

# %%
# %cd training/
# !python3 train_vww.py
# Out:
# /content/training
# 2021-05-13 05:26:54.355351: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-13 05:26:55.991098: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-13 05:26:56.003826: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-05-13 05:26:56.071217: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-13 05:26:56.071825: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...

# %%
! python3 convert_vww.py trained_models/vww_96.h5
# Out:
# 2021-05-13 10:59:34.531588: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-13 10:59:36.812098: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-13 10:59:36.813012: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-05-13 10:59:36.827837: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-13 10:59:36.828521: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...

# %%
! zip -r ../trained_models.zip trained_models/
# Out:
#   adding: trained_models/ (stored 0%)
#   adding: trained_models/vww_96_float.tflite (deflated 8%)
#   adding: trained_models/vww_96_int8.tflite (deflated 74%)
#   adding: trained_models/kws_model.cpp (deflated 79%)
#   adding: trained_models/vww_96.h5 (deflated 45%)

# %%
# %cd ..
# Out:
# /content
